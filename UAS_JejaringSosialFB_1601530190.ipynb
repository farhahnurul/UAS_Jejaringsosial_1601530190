# %%
pip install networkx

# %%
import networkx as nx
import matplotlib.pyplot as plt
from google.colab import drive

drive.mount('/content/drive', force_remount=True)
G1 =nx.read_edgelist('/content/drive/My Drive/facebook_combined.txt', create_using = nx.Graph(), nodetype=int)
# Out:
# Mounted at /content/drive

# %%
print(nx.info(G1))
# Out:
# Name:
# Type: Graph
# Number of nodes: 4039
# Number of edges: 88234
# Average degree:  43.6910

# %% [markdown]
# 1. Analisa menggunakan Betweeness Centrality

# %% [markdown]
# centrality betweenness adalah ukuran sentralitas dalam grafik berdasarkan jalur terpendek. Untuk setiap pasangan simpul dalam grafik yang terhubung, terdapat setidaknya satu jalur terpendek antara simpul sedemikian sehingga jumlah tepi yang dilalui jalur (untuk grafik tidak tertimbang) atau jumlah bobot tepi (untuk grafik tertimbang) ) diminimalkan.

# %%
pos = nx.spring_layout(G1)
betCent = nx.betweenness_centrality(G1, normalized=True, endpoints=True)
node_color = [20000.0 * G1.degree(v) for v in G1]
node_size =  [v * 10000 for v in betCent.values()]
plt.figure(figsize=(20,20))
nx.draw_networkx(G1, pos=pos, with_labels=False,
                 node_color=node_color,
                 node_size=node_size )
plt.axis('off')
sorted(betCent, key=betCent.get, reverse=True)[:5]
# Out:
# [107, 1684, 3437, 1912, 1085]

# %% [markdown]
# 2. Analisa menggunakan Degree Centrality

# %% [markdown]
# Derajat Sentralitas adalah ukuran sentralitas yang paling sederhana untuk dihitung. Ingatlah bahwa derajat simpul hanyalah hitungan dari berapa banyak koneksi sosial yang dimilikinya. Derajat sentralitas untuk sebuah simpul hanyalah tingkatannya.

# %%
pos = nx.spring_layout(G1)
degCent = nx.degree_centrality(G1)
node_color = [20000.0 * G1.degree(v) for v in G1]
node_size =  [v * 10000 for v in degCent.values()]
plt.figure(figsize=(15,15))
nx.draw_networkx(G1, pos=pos, with_labels=False,
                 node_color=node_color,
                 node_size=node_size )
plt.axis('off')

sorted(degCent, key=degCent.get, reverse=True)[:5]
# Out:
# [107, 1684, 1912, 3437, 0]

# %% [markdown]
# 3. Analisa menggunakan Closeness Centrality

# %% [markdown]
# Kedekatan Sentralitas adalah jarak rata-rata antara node dengan semua node yang lain di jaringan. Ukuran ini menggambarkan kedekatan node ini dengan node lain.  Semakin dekat, semakin terhubung orang tersebut dengan lainnya.   Analoginya adalah tipe orang “gaul” yang kenal dengan semua orang akan memiliki pengaruh yang lebih besar karena dapat menyebarkan informasi lebih cepat tanpa perlu perantara pihak ketiga. Untuk mengukur jarak terpendek antar node dapat digunakan algoritma Dijkstra.

# %%
pos = nx.spring_layout(G1)
cloCent = nx.closeness_centrality(G1)
node_color = [20000.0 * G1.degree(v) for v in G1]
node_size =  [v * 10000 for v in cloCent.values()]
plt.figure(figsize=(13,13))
nx.draw_networkx(G1, pos=pos, with_labels=False,
                 node_color=node_color,
                 node_size=node_size )
plt.axis('off')
sorted(cloCent, key=cloCent.get, reverse=True)[:5]
# Out:
# [107, 58, 428, 563, 1684]

# %% [markdown]
# 4. Analisa menggunakan Eeigenvector Centrality

# %% [markdown]
# ukuran ini memberikan bobot yang lebih tinggi pada node yang terhubung dengan node yang juga memiliki keterhubungan tinggi. Dapat dikatakan versi rekursif dari degree centrality.

# %%
#pos = nx.spring_layout(G1)
eigCent = nx.eigenvector_centrality(G1)
node_color = [20000.0 * G1.degree(v) for v in G1]
node_size =  [v * 10000 for v in eigCent.values()]
plt.figure(figsize=(15,15))
nx.draw_networkx(G1, pos=pos, with_labels=False,
                 node_color=node_color,
                 node_size=node_size )
plt.axis('off')
# Out:
# (-0.7204128365206182,
#  1.0819244366005383,
#  -1.0120475142964414,
#  0.970697919618171)
